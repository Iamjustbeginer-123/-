# %% [markdown]
# ## Первичный анализ датасета

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('BankChurners.csv')

df.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
# 6  810347208  Existing Customer            51      M                4
# 7  818906208  Existing Customer            32      M                0
# 8  710930508  Existing Customer            37      M                3
# 9  719661558  Existing Customer            48      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# ...

# %%
df1 = df[['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category', 'Months_on_book']]

# %%
df1.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
# 6  810347208  Existing Customer            51      M                4
# 7  818906208  Existing Customer            32      M                0
# 8  710930508  Existing Customer            37      M                3
# 9  719661558  Existing Customer            48      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  Months_on_book
# 0     High School        Married     $60K - $80K          Blue              39
# ...

# %%
df1.info() # Ок, везде 10127 строк и нет Null значений
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CLIENTNUM        10127 non-null  int64
#  1   Attrition_Flag   10127 non-null  object
#  2   Customer_Age     10127 non-null  int64
#  3   Gender           10127 non-null  object
#  4   Dependent_count  10127 non-null  int64
#  5   Education_Level  10127 non-null  object
#  6   Marital_Status   10127 non-null  object
#  7   Income_Category  10127 non-null  object
#  8   Card_Category    10127 non-null  object
#  9   Months_on_book   10127 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 791.3+ KB

# %%
df1.describe() # Данные логически корректны
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000

# %%
df1['CLIENTNUM'].unique # Все клиенты уникальные
# Out:
# <bound method Series.unique of 0        768805383
# 1        818770008
# 2        713982108
# 3        769911858
# 4        709106358
#            ...
# 10122    772366833
# 10123    710638233
# 10124    716506083
# 10125    717406983
# 10126    714337233
# Name: CLIENTNUM, Length: 10127, dtype: int64>

# %%
df1['Attrition_Flag'].unique() # только 2 категории текущий и ушедший пользователь
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
df1['Customer_Age'].describe() # смотрим распределение возраста
# Out:
# count    10127.000000
# mean        46.325960
# std          8.016814
# min         26.000000
# 25%         41.000000
# 50%         46.000000
# 75%         52.000000
# max         73.000000
# Name: Customer_Age, dtype: float64

# %%
plt.hist(df1['Customer_Age'], bins=20) # большинство людей назодиться в возраст 35 - 55 +- 

plt.xlabel('Возраст')
plt.ylabel('Количество людей')
# Out:
# Text(0, 0.5, 'Количество людей')

# %%
df1['Customer_Age'].unique() # с возрастом все хорошо
# Out:
# array([45, 49, 51, 40, 44, 32, 37, 48, 42, 65, 56, 35, 57, 41, 61, 47, 62,
#        54, 59, 63, 53, 58, 55, 66, 50, 38, 46, 52, 39, 43, 64, 68, 67, 60,
#        73, 70, 36, 34, 33, 26, 31, 29, 30, 28, 27])

# %%
df1['Gender'].describe()
# Out:
# count     10127
# unique        2
# top           F
# freq       5358
# Name: Gender, dtype: object

# %%
df1['Gender'].unique() # с полом все ок
# Out:
# array(['M', 'F'], dtype=object)

# %%
df1['Dependent_count'].describe()
# Out:
# count    10127.000000
# mean         2.346203
# std          1.298908
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          5.000000
# Name: Dependent_count, dtype: float64

# %%
df1['Dependent_count'].unique()
# Out:
# array([3, 5, 4, 2, 0, 1])

# %%
plt.hist(df1['Dependent_count'], bins=12) # кол-во иждевенцев
# Out:
# (array([ 904.,    0., 1838.,    0., 2655.,    0.,    0., 2732.,    0.,
#         1574.,    0.,  424.]),
#  array([0.        , 0.41666667, 0.83333333, 1.25      , 1.66666667,
#         2.08333333, 2.5       , 2.91666667, 3.33333333, 3.75      ,
#         4.16666667, 4.58333333, 5.        ]),
#  <BarContainer object of 12 artists>)

# %%
df1['Education_Level'].unique()
# Out:
# array(['High School', 'Graduate', 'Uneducated', 'Unknown', 'College',
#        'Post-Graduate', 'Doctorate'], dtype=object)

# %%
df1['Education_Level'].describe()
# Out:
# count        10127
# unique           7
# top       Graduate
# freq          3128
# Name: Education_Level, dtype: object

# %%
plt.hist(df1['Education_Level'], bins=15) # большинство людей имеют степень бакалавра 
plt.xticks(rotation=45)

plt.show()

# %%
mode_education = df1['Education_Level'].mode()[0]

df1.loc[:, 'Education_Level'] = df1['Education_Level'].replace('Unknown', mode_education) # заменяем неизвестное значение на модаьное

# %%
mode_status = df1['Marital_Status'].mode()[0]

df1.loc[:, 'Marital_Status'] = df1['Marital_Status'].replace('Unknown', mode_status) # заменяе значения Unknown на моду

# %%
plt.hist(df1['Marital_Status'], bins=10) # большинство юдей женаты 

plt.show()

# %%
mode_income = df1['Income_Category'].mode()[0]

df1.loc[:, 'Income_Category'] = df1['Income_Category'].replace('Unknown', mode_income) # заменяем значения Unknown на моду

# %%
plt.hist(df1['Income_Category']) # большинство людей зарабатывают меньше чем 40к

plt.show()

# %%
df1.loc[:, 'Card_Category'].unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
df1.loc[:, 'Card_Category'].describe()
# Out:
# count     10127
# unique        4
# top        Blue
# freq       9436
# Name: Card_Category, dtype: object

# %%
plt.hist(df1.loc[:, 'Card_Category']) # голубая карта самая популярная среди клиентов 

plt.show()

# %%
df1.loc[:, 'Months_on_book'].unique()
# Out:
# array([39, 44, 36, 34, 21, 46, 27, 31, 54, 30, 48, 37, 56, 42, 49, 33, 28,
#        38, 41, 43, 45, 52, 40, 50, 35, 47, 32, 20, 29, 25, 53, 24, 55, 23,
#        22, 26, 13, 51, 19, 15, 17, 18, 16, 14])

# %% [markdown]
# ## Итоги первичного анализа:

# %% [raw]
# С данными все хорошо аномалий нету. Пришлось заменить некоторые значения "Unknown" в полях об информации о клиентах на моду, чтобы приблизить данные к реальным.
#
# Модальный портрет клиента банка:
# 1.Доход меньше 40K долларов
# 2.Средний возраст клиентов 35-55 лет
# 3.Самый популярный пол - женский
# 4.Кол-во иждевенцев у клиента 3
# 5.Образование клиента - бакалавр
# 6.Статус - женат/жената
# 7.Карта банка - голубая

# %% [markdown]
# ## Как расчитать с помощью наших данных стоит ли давать кредит клиенту?

# %% [raw]
# Income_Category -  характеризует доход клиента чем больше он зарабатывает, тем больше баллов мы ему даем.
# Customer_Age - возраст клиента, чем старше клиент, тем ему сложнее отдавать кредит, поэтому банку легче инвестировать в более молодых и амбициозных людей.
# Months_on_book - стаж клиента, чем больше клиент пользуется банком, тем больше мы знаем о нем персональной информации и тем больше мы уверены, что он предан банку.
# Dependent_count - количество людей нахоящихся на полном финансовом обеспечении клиента, чем больше людей находящихся в обеспечении клиента, тем тяжелее клиенту будет выплачивать кредит в будущем
# Education_Level - уровень образования, чем образованее клиент, тем он успешнее, богаче, умнее (обычно) => тем легче ему будет выплачивать кредит.
# Card_Category - уровень карты характеризует привязаность клиента и его финансовую состоятельность, чем круче карта, тем клиента более интересен для  нас.
# Marital_Status - люди в браке для нас более привлекательные, потому что эти люди уже достаточно обеспеченные, чтобы выплачивать кредит.

# %% [markdown]
# ### Реализация

# %% [markdown]
# ### Расчитываем вероятность банкротства. Модель RandomForestClassifier

# %% [markdown]
# ### Т.к модель легче работать с цифрами, чем с строками, то нам нужно закодировать наши признаки для модели

# %%
# Кодируем значения образования 
def education_encoded(education): 
    if education == 'Doctorate':
        return 6 
    elif education == 'Post-Graduate':
        return 5
    elif education == 'Graduate':
        return 4
    elif education == 'College':
        return 3
    elif education == 'High School':
        return 2
    else:  
        return 1

# Кодируем значения дохода
def income_encoded(income): 
    if income == '$120K +':
        return 5
    elif income == '$80K - $120K':
        return 4
    elif income == '$60K - $80K':
        return 3
    elif income == '$40K - $60K':
        return 2
    elif income == 'Less than $40K':
        return 1

# Кодируем значения типа карты 
def card_type_encoded(card): 
    if card == 'Gold':
        return 4
    elif card == 'Platinum':
        return 3
    elif card == 'Silver':
        return 2
    else:  
        return 1

def married_encoded(maritial): 
    if maritial == 'Married':
        return 2
    else: 
        return 1
df1.loc[:, 'Education_Level_encoded'] = df1['Education_Level'].apply(education_encoded)
df1.loc[:, 'Income_Category_encoded'] = df1['Income_Category'].apply(income_encoded)
df1.loc[:, 'Card_Category_encoded'] = df1['Card_Category'].apply(card_type_encoded)
df1.loc[:, 'Marital_Status_encoded'] = df1['Marital_Status'].apply(married_encoded)
# Out:
# C:\Users\Админ\AppData\Local\Temp\ipykernel_16828\1763246481.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[:, 'Education_Level_encoded'] = df1['Education_Level'].apply(education_encoded)
# C:\Users\Админ\AppData\Local\Temp\ipykernel_16828\1763246481.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[:, 'Income_Category_encoded'] = df1['Income_Category'].apply(income_encoded)
# ...

# %%
df1.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
# 6  810347208  Existing Customer            51      M                4
# 7  818906208  Existing Customer            32      M                0
# 8  710930508  Existing Customer            37      M                3
# 9  719661558  Existing Customer            48      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# ...

# %% [markdown]
# ## Модель расчитывающая вероятность банкротства клиента по колонке Attrition_Flag

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# Передача данных 
X = df1[['Customer_Age', 'Dependent_count', 'Months_on_book', 'Education_Level_encoded',
        'Income_Category_encoded', 'Card_Category_encoded', 'Marital_Status_encoded']]
y = (df1['Attrition_Flag'] == 'Attrited Customer').astype(int)

# Обучение
model = RandomForestClassifier()
model.fit(X, y)

# Предсказание вероятности банкротства 
df1.loc[:, 'default_probability'] = model.predict_proba(X)[:, 1]
# Процент *надежности клиента
df1.loc[:, 'credit_score_percent'] = (1 - df1['default_probability']) * 100 

accuracy = model.score(X, y)
print(f"Вероятность получить верное значение моделью: {accuracy:.4f}")
# Out:
# Вероятность получить верное значение моделью: 0.9669

# %%
df1['Education_Level_encoded'].unique()
# Out:
# array([2, 4, 1, 3, 5, 6])

# %%
df1.loc[:, 'Attrition_Flag'].unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
df1.sample(5)
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 2380  713445183  Existing Customer            35      M                1
# 1657  711145008  Existing Customer            60      F                1
# 2560  826706208  Existing Customer            55      M                3
# 6695  711428733  Existing Customer            50      F                3
# 9117  711339258  Existing Customer            49      F                3
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 2380     High School        Married     $60K - $80K          Blue
# 1657        Graduate        Married     $40K - $60K          Blue
# 2560        Graduate         Single    $80K - $120K          Blue
# 6695   Post-Graduate       Divorced     $40K - $60K          Blue
# 9117        Graduate         Single     $40K - $60K        Silver
#
#       Months_on_book  Education_Level_encoded  Income_Category_encoded  \
# ...

# %%
df1[['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category']].to_csv('customers_analysis_bank_sphere.csv')
